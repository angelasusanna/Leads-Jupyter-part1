# %% [markdown]
# ***
# # 1. Introduction to Jupyter
# ***
# > **Learn how to work with the notebook:** <br>
# -how to add cells, change cell types, edit and run cells <br>
# -how to set the different cell types: mark down, code, raw <br>
# -how to format text in mark down cells <br>
# -mini exercise
#
# <br>
# <br>
# **A Jupyter notebook consists of cells that can store text (and figures, equations,etc) or code. There are 3 types of cells:**
# 1. Code cells - this is where you will write your python commands
# 2. Markdown cells- these cells can hold explanatory text and figures
# 3. Raw cells - these are cells with no formatting and are of use if your intend to convert your notebook to another format using the command line too nbconvert

# %% [markdown]
# ***
# ## 1.1 Creating and editing cells
# ***

# %% [markdown]
# Note that there is an `editing menu on the top of this notebook`. Hoover over the symbols to see the different tools, like: save, insert a cell below, cut, copy and paste cells, run the cell, interrupt the kernel (the server that runs the code), etc.
#
# **Create a new cell:**
# - Use the + sign on the upper left top of this notebook
# - Keyboard shortcut `ESC + a` - add a new cell above the current
# - Keyboard shortcut `ESC + b` - add a new cell below the current
#
# **Cell type:**<br>
# When you create a cell, the default will be a `code` cell. You can change the type from the top menu of the notebook to `code` or `raw`.

# %% [markdown]
# ### `Double-click` this cell (markdown cell) to EDIT it (or click ENTER to EDIT)
#
# **`SHIFT-ENTER` to render the cell, or click on the `PLAY` symbol on top of this notebook.**

# %% [markdown]
# ***
# ## 1.2 Format your Markdown cells
# ***
#
# ## Remember - Double - click the cell to Edit!
#
# # Here is a heading one
# ## and a heading two
# ### and a heading three
# #### and a heading four
#
# **this syntax bolds text in markdown**
#
# 1. This is a number list
#
# * and this is a bullet list
#
# * **and this is a bullet list with bold words!**
#
# *This is how you italicize your words*
#
# `This is how you highlight something` <br>
# You use the back-tick symbol, usually on the same keyboard key as the tilde (~) <br>
# Use `br` between <> to go to the next line.
#
# ***
# This is how you create horizontal lines
# ***
#
#
# This is how you create hyperlinks:
# 1. [jupyter site](https://jupyter.org/)
# 2. [Jupyter Widgets](https://ipywidgets.readthedocs.io/en/latest/index.html) and
# 3. [Voilà dashboards](https://voila.readthedocs.io/en/latest/?badge=latest)
#
# You can also use HTML to create hyperlinks, this is the syntax:
# `<a href="url" target="_blank">hyperlinked words</a>`
#
# For example, <a href="http://earthdatascience.org" target="_blank"> Click on this link to visit the Earth Data Science website </a>

# %% [markdown]
# ***
# This is how you add figures to your notebook!
# ***
#
# <img src="https://i.pinimg.com/564x/fa/0b/b2/fa0bb2d50840d16c94388d75cc01387e.jpg" align="center">
#
# <br>
# <br>
#
# OR
# You can just **drag and drop** a picture from your drive directly into the cell!
#
# ![GeostationaryOrbitView (3).jpg](attachment:15dc5572-a640-47ed-a18f-5e853a2f5f06.jpg)

# %%
# To zip your Jupyter folder for download
# Open the terminal
#zip -r LEADS_Python_Jupyter.zip LEADS_Python_Jupyter

# %% [markdown]
# ***
# ## 1.3 Your turn!
# ***
#
# ## Part I
# 1. Open a new Jupyter notebook (Go to the main menu on top of your site > Click on `FILE` > `NEW` > `NOTEBOOK`
#
# 2. You will be asked to select a kernel, choose the python3 as shown below and click `Select`
#
# ![image.png](attachment:ab44a7f9-b8ce-4283-b375-7254d4a0fd0a.png)
#
# 3. Your new notebook should appear in your Table of content (file tree) on the left > right-click the new file (Untitled.ipynb) > Rename > call it **Exercises**
#
# 4. Open the **Exercises** notebook you just created by double-clicking it.
#
# 5. Add three cells here below using one of the methods shown above. Set one cell as `Markdown`, one as `Code` and one as `Raw`

# %% [markdown]
# ***
# ## Part II
# In your `Markdown` cell, add the following:
# 1. A Chapter heading saying something like: Introduction to Jupyter - my notes
# 2. Summarize what you learned about Jupyter in a bullet point list
# 3. Add a hyperlink to a website you like a lot
# 4. Add a picture you like to the cell
#
# In your `Code` and `Raw` cells add the following: <br>
# #Python Code <br>
# print ('Hello Everyone!!!')
#
# What happens?
